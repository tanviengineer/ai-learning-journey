# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas Series

# %%
# a series is a 1D array and capable to hold diff datatypes , the axies labels are collectively called the index

# %%
labels =["a","b","c"]
my_list =[10,20,30]
arr = np.array([10,20,30])
d= {1:10,2:20, 3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index =labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# DATAFRAME

# %%
import numpy as np
import pandas as pd

# %%
# CREATING A DATAFRAME

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df= pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2= pd.DataFrame(data_list)
columns = ["Name", "Age", "City","Salary"]
df3= pd.DataFrame(data_list ,columns=columns)

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# selection and indesing of columns

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
df3["Name"]
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df3[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
# creating a new columns

# %%
df3["Designation"]=["Doctor","Engineer","Docter","Engineer"]

# %%
df3
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000      Docter
# 3  Linda   42    London   85000    Engineer

# %%
# removing columns

# %%
df3.drop("Designation",axis=1, inplace = True)
# vertical is axis 1 and horizontal is axis 0

# %%
# inplace is used to parmenataly selection of colume ,otherwise it just create a copy of it

# %%
df3
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
# selecting rows

# %%
df2.loc[0]
# loc is a location
# Out:
# 0        John
# 1          28
# 2    New York
# 3       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1]]
# Out:
#       0   1         2      3
# 0  John  28  New York  65000
# 1  Anna  34     Paris  70000

# %%
df.iloc[3]
# iloc is a location of index
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %%
# selecting subsets of rowa and columns

# %%
df.loc[[0,1]][["City","Salary"]]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
# conditional selection

# %%
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000
