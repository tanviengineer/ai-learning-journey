# %% [markdown]
# <a href="https://colab.research.google.com/github/tanviengineer/ai-learning-journey/blob/main/data_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Matplotlib basics

# %%
x =np.linspace(0,5,11)
y=x**3
x
y
# Out:
# array([  0.   ,   0.125,   1.   ,   3.375,   8.   ,  15.625,  27.   ,
#         42.875,  64.   ,  91.125, 125.   ])

# %%
plt.plot(x,y)
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("hello")
# plt.show()
# Out:
# Text(0.5, 1.0, 'hello')

# %% [markdown]
# # SUB PLOTS  in MATPLOTLIB

# %%
# plt.subplot(2,2)
plt.subplot(2,2,1)
plt.plot(y**2,x**3)
plt.subplot(2,2,2)
plt.plot(x,y)
plt.subplot(2,2,3)
plt.plot(y,y)
plt.subplot(2,2,4)
plt.plot(x,x)

# %%
x = np.array([10,20,30,40,50])
y = x**2

# %%
plt.plot(x,y)
plt.xlabel("x axis ")
plt.ylabel("y axis ")
plt.title("title of the graph")
# Out:
# Text(0.5, 1.0, 'title of the graph')

# %%
plt.subplot(2,2, 1)
plt.plot( x,x)
plt.subplot(2,2,2 )
plt.plot( x,y)
plt.subplot(2,2, 3)
plt.plot( y,x)
plt.subplot(2,2,4 )
plt.plot( y,y)
# plt.savefig("subplot.png")

# %% [markdown]
# # OBJECT ORIENTED WAY

# %%
fig = plt.figure()
axis1 = fig.add_axes([0.1,0.1,0.8,0.8])
axis1.plot(x,y)
# 0.1 → start 10% from the left
# 0.1 → start 10% from the bottom
# 0.8 → plot takes 80% of figure width
# 0.8 → plot takes 80% of figure height

# %%
fig = plt.figure()
axis2 =fig.add_axes([0.1,0.1,1,1])
axis2.plot(x,y)
axis3 =fig.add_axes([0.2,0.6,0.2,0.2])
axis3.plot(x,y)

# %%
# fig size (weight , length , of the canvaes)
fig =plt.figure(figsize= (2,2))
axis1 = fig.add_axes([1,1,0.8,0.8])

# %%
# dpi = depth per inch
# when we increase a dpi quality of figure is more clear but it take high computational power
fig =plt.figure(figsize= (2,2),dpi = 100)
axis1 = fig.add_axes([1,1,0.8,0.8])

# %% [markdown]
# types of plot

# %%
plt.scatter(x,y)
# scatter

# %%
plt.hist(x)
# Out:
# (array([1., 0., 1., 0., 0., 1., 0., 1., 0., 1.]),
#  array([10., 14., 18., 22., 26., 30., 34., 38., 42., 46., 50.]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7d2d7bbced50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7d2d7bbcf320>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7d2d7be02630>],
#  'medians': [<matplotlib.lines.Line2D at 0x7d2d7bbcf980>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7d2d7bbcfc50>],
#  'means': []}

# %% [markdown]
# saving plot

# %%
fig =plt.figure()
ax =fig.add_axes([0.1,0.1,0.8,0.8])
ax.plot(x,y)
plt.savefig("basic.png")

# %% [markdown]
# working with image

# %%
import matplotlib.image as mpimg

# %%
img = mpimg.imread("/content/PHOTO.jpeg")
plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(1251.5), np.float64(1279.5), np.float64(-0.5))

# %% [markdown]
# optinal designing

# %%
plt.plot(x,y,color ="pink")

# %% [markdown]
# Distributed plots **

# %%
# We use distribution plots to visualize the distribution of quantitative data.

# Let's discuss some plots that allow us to visualize the distribution of a data set. These plots are:

# distplot/histplot
# jointplot
# pairplot
# rugplot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df =sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df["size"].unique()
# so this colume also consider as a qanlitative (cetagires ) columns
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
sns.displot(df['total_bill'])

# %%
sns.displot(df['total_bill'], bins=20)

# %%
plt.subplot(1,2,1)
sns.histplot(df['total_bill'],bins= 20,kde=True)
plt.subplot(1,2,2)
sns.histplot(df['tip'],bins= 20,kde=True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
# jointplot
# heplt to use compare the two colums
sns.jointplot(x =df["total_bill"] , y =df["tip"])

# %%
sns.jointplot(x ="total_bill", y = "tip", data= df)

# %%
sns.jointplot(x ="total_bill", y = "tip", data= df,kind ="kde")

# %%
sns.jointplot(x ="total_bill", y = "tip", data= df,kind="hex")

# %%
sns.jointplot(x ="total_bill", y = "tip", data= df, kind ='reg')

# %%
sns.jointplot(x ="total_bill", y = "tip", data= df, kind ='scatter')

# %%
# PAIR PLOT

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue ="sex" ,palette ="rainbow")
# hue is used to define the data into categories

# %%
sns.pairplot(df , hue ="size")

# %%
# rugplot
sns.rugplot(df)
# Out:
# <Axes: >

# %%
sns.rugplot(df['total_bill'])
# Out:
# <Axes: xlabel='total_bill'>

# %% [markdown]
# **categorical plots**

# %%
# Now let's discuss using seaborn to plot categorical data! There are a few main plot types for this:

# boxplot
# violinplot
# stripplot
# swarmplot
# barplot
# countplot
# Let's go through examples of each!

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =sns.load_dataset("tips")
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# catogies(sex, smoker, dat,time)

# %%
sns.countplot(x =df['sex'])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x =df['sex'],hue =df["smoker"])
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
# barplot( y =quantatative data , x = qualitative (catehied))
sns.barplot(x= df["sex"],y =df["total_bill"])
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x= df["sex"],y =df["tip"])
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# You can change the estimator object to your own function, that converts a vector to a scalar
#  Mean (default): np.mean
# Median: np.median
# Sum: np.sum
# Count: len (to count the number of observations)
# Standard Deviation: np.std
# Minimum: np.min
# Maximum: np.max

# %%
import numpy as np

# %%
sns.barplot(x= df["sex"],y =df["total_bill"],estimator =np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='total_bill'>

# %%
sns.barplot(x= df["sex"],y =df["tip"],estimator =np.sum)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %%
# boxplot
# (y axes = quantitative,numarice)(x axes = qualitative , categorical)

sns.boxplot(x= "tip",y="day", data =df)
# Out:
# <Axes: xlabel='tip', ylabel='day'>

# %% [markdown]
# boxplots and violinplots are used to shown the distribution of categorical data. A box plot (or box-and-whisker plot) shows the distribution of quantitative data in a way that facilitates comparisons between variables or across levels of a categorical variable. The box shows the quartiles of the dataset while the whiskers extend to show the rest of the distribution, except for points that are determined to be “outliers” using a method that is a function of the inter-quartile range.

# %%
# violinplot
sns.violinplot(x =df["day"],y=df["total_bill"])
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# # stripplot and swarmplot

# %% [markdown]
# The stripplot will draw a scatterplot where one variable is categorical. A strip plot can be drawn on its own, but it is also a good complement to a box or violin plot in cases where you want to show all observations along with some representation of the underlying distribution.
#
# The swarmplot is similar to stripplot(), but the points are adjusted (only along the categorical axis) so that they don’t overlap. This gives a better representation of the distribution of values, although it does not scale as well to large numbers of observations (both in terms of the ability to show all the points and in terms of the computation needed to arrange them).

# %%
sns.swarmplot(x= 'day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x= 'day',y='total_bill',data=df)
# Out:
# <Axes: xlabel='day', ylabel='total_bill'>

# %%
sns.violinplot(x= "tip",y="day",data=df)
sns.swarmplot(x= "tip",y="day",data=df)
# Out:
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 9.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 10.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='tip', ylabel='day'>
# /usr/local/lib/python3.12/dist-packages/seaborn/categorical.py:3399: UserWarning: 8.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # **matrix plot**

# %% [markdown]
# Heat map

# %%
import matplotlib.pyplot as plt
import seaborn as snn

# %%
flights =sns.load_dataset("flights")
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
tips =sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tipscorr = tips[['total_bill','tip','size']]
tipscorr
# Out:
#      total_bill   tip  size
# 0         16.99  1.01     2
# 1         10.34  1.66     3
# 2         21.01  3.50     3
# 3         23.68  3.31     2
# 4         24.59  3.61     4
# ..          ...   ...   ...
# 239       29.03  5.92     3
# 240       27.18  2.00     2
# 241       22.67  2.00     2
# 242       17.82  1.75     2
# 243       18.78  3.00     2
#
# [244 rows x 3 columns]

# %%
tipscorr.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tipscorr.corr())
# Out:
# <Axes: >

# %%
sns.heatmap(tipscorr.corr(),annot =True)
# Out:
# <Axes: >

# %% [markdown]
# Cluster map

# %%
sns.clustermap(tipscorr.corr() )

# %% [markdown]
# pivot table Heat map

# %%
pvtflight= flights.pivot_table(values='passengers',index ='month',columns ="year")
# Out:
# /tmp/ipykernel_492/1978257149.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pvtflight= flights.pivot_table(values='passengers',index ='month',columns ="year")

# %%
pvtflight
# Out:
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# Aug    148.0  170.0  199.0  242.0  272.0  293.0  347.0  405.0  467.0  505.0
# Sep    136.0  158.0  184.0  209.0  237.0  259.0  312.0  355.0  404.0  404.0
# Oct    119.0  133.0  162.0  191.0  211.0  229.0  274.0  306.0  347.0  359.0
# Nov    104.0  114.0  146.0  172.0  180.0  203.0  237.0  271.0  305.0  310.0
# ...

# %%
sns.heatmap(pvtflight)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %% [markdown]
# **regression plot **

# %%
# lmplot()
#
# lmplot()
# regression plot is used in machine learning so we will not fully discuss what, how and where it is used but we will see how it is created and what are the values we can put inside it

# %%
# implit( x = put those values that help to predict, y= put that value we have to predict)

# %%
sns.lmplot(x ="total_bill", y ='tip',data =tips)

# %%
sns.lmplot(x ="total_bill", y ='tip',data =tips , hue ='sex')

# %% [markdown]
# ## plotly and cufflinks

# %%
# ploty = it is o=python lib used to design a garph , especially a interactive graphs

# %%
# cufflinks  = connects plotty with pandas to create a graphs and charts of dataframes directly

# %%
# !pip install plotly

# %%
# !pip install cufflinks
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 53.8 MB/s eta 0:00:00
# ...

# %%
from plotly.offline import iplot, init_notebook_mode
import cufflinks as cf
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.35.2.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
tips  = sns.load_dataset ("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # IPL **project**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib .pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("/content/IPL.csv")
df.head()
# Out:
#    match_id           date                                         venue  \
# 0         1  March 26,2022                      Wankhede Stadium, Mumbai
# 1         2  March 27,2022                     Brabourne Stadium, Mumbai
# 2         3  March 27,2022            Dr DY Patil Sports Academy, Mumbai
# 3         4  March 28,2022                      Wankhede Stadium, Mumbai
# 4         5  March 29,2022  Maharashtra Cricket Association Stadium,Pune
#
#        team1      team2  stage toss_winner toss_decision  first_ings_score  \
# 0    Chennai    Kolkata  Group     Kolkata         Field               131
# 1      Delhi     Mumbai  Group       Delhi         Field               177
# 2   Banglore     Punjab  Group      Punjab         Field               205
# 3    Gujarat    Lucknow  Group     Gujarat         Field               158
# 4  Hyderabad  Rajasthan  Group   Hyderabad         Field               210
#
# ...

# %% [markdown]
# basic information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 20 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   match_id             74 non-null     int64
#  1   date                 74 non-null     object
#  2   venue                74 non-null     object
#  3   team1                74 non-null     object
#  4   team2                74 non-null     object
#  5   stage                74 non-null     object
#  6   toss_winner          74 non-null     object
#  7   toss_decision        74 non-null     object
#  8   first_ings_score     74 non-null     int64
#  9   first_ings_wkts      74 non-null     int64
#  10  second_ings_score    74 non-null     int64
#  11  second_ings_wkts     74 non-null     int64
#  12  match_winner         74 non-null     object
#  13  won_by               74 non-null     object
#  14  margin               74 non-null     int64
# ...

# %%
df.shape
# rows ,columns
# Out:
# (74, 20)

# %%
df.isnull().sum()
# Out:
# match_id               0
# date                   0
# venue                  0
# team1                  0
# team2                  0
# stage                  0
# toss_winner            0
# toss_decision          0
# first_ings_score       0
# first_ings_wkts        0
# second_ings_score      0
# second_ings_wkts       0
# match_winner           0
# won_by                 0
# margin                 0
# player_of_the_match    0
# top_scorer             0
# highscore              0
# best_bowling           0
# best_bowling_figure    0
# dtype: int64

# %%
match_wins =df['match_winner'].value_counts()
match_wins
# Out:
# match_winner
# Gujarat      12
# Rajasthan    10
# Banglore      9
# Lucknow       9
# Punjab        7
# Delhi         7
# Kolkata       6
# Hyderabad     6
# Chennai       4
# Mumbai        4
# Name: count, dtype: int64

# %%
sns.barplot(y=match_wins.index, x = match_wins.values)
# Out:
# <Axes: ylabel='match_winner'>

# %%
sns.countplot(x= df["toss_decision"])
# Out:
# <Axes: xlabel='toss_decision', ylabel='count'>

# %%
# toss winer vs match winner
count= df[df['toss_winner']==df['match_winner']]["match_id"].count()
percentage = (count*100)/df.shape[0]
percentage
# Out:
# np.float64(48.648648648648646)
